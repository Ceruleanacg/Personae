# %%
# %load_ext rqalpha
# Out:
# The rqalpha extension is already loaded. To reload it, use:
#   %reload_ext rqalpha

# %%
config = {
  "base": {
    "start_date": "2010-01-01",
    "end_date": "2018-01-01",
    "benchmark": "000300.XSHG",
    "accounts": {
        "stock": 100000
    }
  },
  "extra": {
    "log_level": "verbose",
  },
  "mod": {
    "sys_analyser": {
      "enabled": True,
      "plot": True
    }
  }
}

# %%
import rqalpha

from rqalpha.api import *

def init(context):
    print(all_instruments(type='Future'))


def handle_bar(context, bar_dict):
    print(instruments('AU888', 2000, '1d'))

rqalpha.run_func(init=init, config=config)
# Out:
# [2018-04-13 15:11:28.488099] DEBUG: basic_system_log:
# {'base': {'accounts': {'STOCK': 100000.0},
#           'benchmark': '000300.XSHG',
#           'data_bundle_path': '/Users/shuyu/.rqalpha/bundle',
#           'end_date': datetime.date(2018, 1, 1),
#           'frequency': '1d',
#           'init_positions': [],
#           'margin_multiplier': 1,
#           'persist': False,
#           'persist_mode': PERSIST_MODE.REAL_TIME,
#           'resume_mode': False,
#           'run_type': RUN_TYPE.BACKTEST,
#           'source_code': None,
#           'start_date': datetime.date(2010, 1, 1),
#           'strategy_file': 'strategy.py'},
#  'extra': {'context_vars': None,
#            'dividend_reinvestment': False,
#            'enable_profiler': False,
#            'force_run_init_when_pt_resume': False,
#            'is_hold': False,
#            'locale': 'zh_Hans_CN',
#            'log_level': 'verbose',
#            'logger': [],
#            'user_log_disabled': False,
# ...

# %%
import rqalpha

from rqalpha.api import *

print(instruments('AU888', 2000, '1d'))
# Out:
# ----------------------------------------------------------------
# RuntimeError                   Traceback (most recent call last)
# <ipython-input-27-2a9a1786a6bb> in <module>()
#       3 from rqalpha.api import *
#       4
# ----> 5 print(instruments('AU888', 2000, '1d'))
#
# /Users/shuyu/anaconda3/envs/quant/lib/python3.5/site-packages/rqalpha/execution_context.py in wrapper(*args, **kwargs)
#     103                 if phase not in phases:
#     104                     raise patch_user_exc(
# --> 105                         RuntimeError(_(u"You cannot call %s when executing %s") % (func.__name__, phase.value)))
#     106                 return func(*args, **kwargs)
#     107             return wrapper
#
# RuntimeError: instruments 不能在 [全局] 中调用。
